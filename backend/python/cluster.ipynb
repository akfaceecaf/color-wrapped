139,255],[130,118,89,255],[127,79,139,255],[112,126,141,255],[96,87,78,255],[214,65,51,255],[94,87,83,255],[78,125,132,255],[29,43,132,255],[154,145,166,255],[250,249,248,255],[177,176,174,255],[134,108,90,255],[152,142,121,255],[111,103,108,255],[69,51,55,255],[135,124,106,255],[201,77,118,255],[75,67,68,255],[103,46,46,255],[98,134,160,255],[155,148,136,255],[111,102,77,255],[107,108,104,255],[115,120,108,255],[175,173,172,255],[112,116,117,255],[170,171,171,255],[88,80,76,255],[153,135,118,255],[175,178,179,255],[70,111,159,255],[141,145,114,255],[115,103,69,255],[171,142,136,255],[29,29,29,255],[232,224,218,255],[72,60,71,255],[24,57,175,255],[149,125,121,255],[138,133,99,255]],"names":["HOLDIN' ON","NOT CUTE ANYMORE","You're Not The Only One I Know","You're Gonna Tell Me","Have A Baby (With Me)","HIGHJACK","It's Called: Freefall","Sweater Weather","Ghost Town","Human Sacrifice","These Days","Doin What I Want","SUPERPOSITION (feat. John Mayer)","NASCAR","Available","Hate to See Your Heart Break","Die For You","Always","DAYLIGHT DOOM","Wrong Time","Seasons (Waiting on You)","Tennessee","Yamaha","Paul","Why","Biking","The Question","Spirals","Who Knows","If It Wasn't For The Nights","No One Else Like You","Nothin' on You (feat. Bruno Mars)","misses","Some Things","Please Come Home for Christmas - 2013 Remaster","in the pool","instagram","I Caught Myself","So Far Above Me (Broke and Breaking)","Young Folks","Scream Drive Faster","That's Life","Never Say Never","29 Intro","Playing with Fire","I'll Take Care of You (feat. Yebba)","Midnight City","Delilah (pull me out of this)","Shock The World - Melody Version","It Feels the Same Everyday"]}"""

# %%
import json

# %%
mock = json.loads(raw)

# %%
from sklearn.cluster import HDBSCAN, KMeans
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
import json

# %%
min_cluster_size = 3
min_samples = 2

# %%
model = HDBSCAN(min_cluster_size=min_cluster_size, min_samples=min_samples)

# %%
n_clusters = 8

# %%
model = KMeans(n_clusters=n_clusters)

# %%
vectors = np.array(mock['vectors'])
colors = np.array(mock['color'])[:,:3]/255
names = np.array(mock['names'])

# %%
preds = model.fit_predict(vectors)
# Out:
# /opt/anaconda3/envs/color-wrapped/lib/python3.11/site-packages/sklearn/cluster/_hdbscan/hdbscan.py:722: FutureWarning: The default value of `copy` will change from False to True in 1.10. Explicitly set a value for `copy` to silence this warning.
#   warn(

# %%
mask = preds >= -2
fig, ax = plt.subplots(figsize=(15, 10))

ax.scatter(vectors[mask, 0], vectors[mask, 1],  
           color=colors[mask], s=10000)

for i, n in enumerate(names):
    if mask[i]:
        ax.text(vectors[i, 0], vectors[i, 1], n, 
                fontsize=12, ha='center', va='bottom')

plt.show()

# %%
import plotly.express as px

# %%
fig = px.scatter(x=vectors[:,0], y=vectors[:,1],color=preds.astype(str))
fig.show()

# %%
fig, ax = plt.subplots(figsize=(15,10))
ax.scatter(vectors[:,0], vectors[:,1], c=preds, cmap='tab10')

for i, n in enumerate(names):
    ax.text(vectors[i,0], vectors[i,1],n, fontsize=6, ha='center', va='bottom')
